# %%
import numpy as np
import pandas as pd
import matplotlib as pt
import seaborn as sns

# %%
df=pd.read_csv("ozone_layer_reduction_final.csv")
df
# Out:
#        Timestamp         Region   UV_Index  CO2_Levels_ppm  Temperature_C  \
# 0     2021-08-06  South America  10.145763      401.316616      27.861482
# 1     2015-08-20           Asia   7.196656      433.420665      11.011478
# 2     2024-04-22     Antarctica   8.115893      361.952708      39.873028
# 3     2020-03-08         Arctic  11.491595      420.800486      13.550275
# 4     2019-03-31     Antarctica   6.354901      439.679859     -38.510968
# ...          ...            ...        ...             ...            ...
# 4995  2022-07-14           Asia   2.213279      378.016610      -9.045612
# 4996  2018-07-03      Australia   7.862811      369.195443     -21.507598
# 4997  2015-10-26  South America   6.251022      384.675160     -49.677700
# 4998  2018-11-16         Arctic   6.800567      400.337262      27.380588
# 4999  2019-08-12         Arctic   4.878815      420.599162      -4.602821
#
#       CFC_Levels_ppt  Ozone_Concentration_DU
# 0           0.307341              290.686439
# 1           0.572824              254.246420
# 2           0.355891              274.575867
# 3           0.310991              283.778325
# 4           0.265823              275.152667
# ...              ...                     ...
# 4995        0.352888              277.801333
# 4996        0.764901              264.088467
# 4997        0.551999              263.484352
# 4998        0.538679              291.334693
# 4999        0.605658              251.046524
#
# [5000 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               5000 non-null   object
#  1   Region                  5000 non-null   object
#  2   UV_Index                5000 non-null   float64
#  3   CO2_Levels_ppm          5000 non-null   float64
#  4   Temperature_C           5000 non-null   float64
#  5   CFC_Levels_ppt          5000 non-null   float64
#  6   Ozone_Concentration_DU  5000 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#           UV_Index  CO2_Levels_ppm  Temperature_C  CFC_Levels_ppt  \
# count  5000.000000     5000.000000    5000.000000     5000.000000
# mean      6.914080      400.588359      -0.155216        0.450828
# std       2.902098       28.809667      28.583783        0.201796
# min       2.000236      350.034551     -49.974680        0.100040
# 25%       4.363610      375.901794     -24.595693        0.279167
# 50%       6.837791      400.667868      -0.646301        0.450869
# 75%       9.406884      425.548696      24.415414        0.623250
# max      11.999923      449.974931      49.982938        0.799536
#
#        Ozone_Concentration_DU
# count             5000.000000
# mean               277.475955
# std                 14.214751
# min                222.915513
# 25%                267.673384
# 50%                277.493457
# 75%                287.401988
# max                325.067315

# %%
df.isnull().sum()
# Out:
# Timestamp                 0
# Region                    0
# UV_Index                  0
# CO2_Levels_ppm            0
# Temperature_C             0
# CFC_Levels_ppt            0
# Ozone_Concentration_DU    0
# dtype: int64

# %%
#Encoding Region column 
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df["Region"]=l.fit_transform(df["Region"])
df.head()
# Out:
#     Timestamp  Region   UV_Index  CO2_Levels_ppm  Temperature_C  \
# 0  2021-08-06       7  10.145763      401.316616      27.861482
# 1  2015-08-20       3   7.196656      433.420665      11.011478
# 2  2024-04-22       1   8.115893      361.952708      39.873028
# 3  2020-03-08       2  11.491595      420.800486      13.550275
# 4  2019-03-31       1   6.354901      439.679859     -38.510968
#
#    CFC_Levels_ppt  Ozone_Concentration_DU
# 0        0.307341              290.686439
# 1        0.572824              254.246420
# 2        0.355891              274.575867
# 3        0.310991              283.778325
# 4        0.265823              275.152667

# %%
#Deleting timestamp columbn as it is of no use
df.drop(columns="Timestamp",inplace=True)
df.head()
# Out:
#    Region   UV_Index  CO2_Levels_ppm  Temperature_C  CFC_Levels_ppt  \
# 0       7  10.145763      401.316616      27.861482        0.307341
# 1       3   7.196656      433.420665      11.011478        0.572824
# 2       1   8.115893      361.952708      39.873028        0.355891
# 3       2  11.491595      420.800486      13.550275        0.310991
# 4       1   6.354901      439.679859     -38.510968        0.265823
#
#    Ozone_Concentration_DU
# 0              290.686439
# 1              254.246420
# 2              274.575867
# 3              283.778325
# 4              275.152667

# %%
x=df.iloc[:,0:5]
x
# Out:
#       Region   UV_Index  CO2_Levels_ppm  Temperature_C  CFC_Levels_ppt
# 0          7  10.145763      401.316616      27.861482        0.307341
# 1          3   7.196656      433.420665      11.011478        0.572824
# 2          1   8.115893      361.952708      39.873028        0.355891
# 3          2  11.491595      420.800486      13.550275        0.310991
# 4          1   6.354901      439.679859     -38.510968        0.265823
# ...      ...        ...             ...            ...             ...
# 4995       3   2.213279      378.016610      -9.045612        0.352888
# 4996       4   7.862811      369.195443     -21.507598        0.764901
# 4997       7   6.251022      384.675160     -49.677700        0.551999
# 4998       2   6.800567      400.337262      27.380588        0.538679
# 4999       2   4.878815      420.599162      -4.602821        0.605658
#
# [5000 rows x 5 columns]

# %%
y=df["Ozone_Concentration_DU"]
y
# Out:
# 0       290.686439
# 1       254.246420
# 2       274.575867
# 3       283.778325
# 4       275.152667
#            ...
# 4995    277.801333
# 4996    264.088467
# 4997    263.484352
# 4998    291.334693
# 4999    251.046524
# Name: Ozone_Concentration_DU, Length: 5000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error,r2_score
m=mean_absolute_error(ytest,ypred)
r2=r2_score(ytest,ypred)

print("Mean Absolute error : ", m)
print("R2 Score : ",r2)
# Out:
# Mean Absolute error :  7.954038180618307
# R2 Score :  0.48613244143667045
